# %% [markdown]
# ## Launch Sites Locations Analysis with Folium

# %% [markdown]
# ### Objectives
# Tis lab contains the following tasks:
#
# . TASK 1: Mark all launch sites on a map
#
# . TASK 2: Mark the success/failed launches for each site on the map
#
# . TASK 3: Calculate the distances between a launch site to its proximities

# %%
# !pip install pandas
# !pip install folium
import folium
import pandas as pd
from folium.plugins import MarkerCluster
from folium.plugins import MousePosition
from folium.features import DivIcon
# Out:
# Requirement already satisfied: pandas in /Users/josethorex/anaconda3/lib/python3.11/site-packages (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.15.4 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: folium in /Users/josethorex/anaconda3/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/josethorex/anaconda3/lib/python3.11/site-packages (from requests->folium) (2023.7.22)

# %%
# Task 1: Mark all launch sites on a map
URL = ("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_2.csv")
data = pd.read_csv(URL)  # Cambiado el nombre del DataFrame a 'data'

# Crear un mapa centrado en una ubicación específica (puedes ajustar las coordenadas según tus necesidades)
map_center = [0, 0]  # Latitud, Longitud
map_spacex = folium.Map(location=map_center, zoom_start=2)

# Iterar sobre los datos y agregar marcadores al mapa
for index, launch_site in data.iterrows():  # Cambiado el nombre del DataFrame a 'data'
    folium.Marker(
        location=[launch_site['Latitude'], launch_site['Longitude']],
        popup=launch_site['LaunchSite'],
        icon=folium.Icon(color='blue', icon='rocket'),
    ).add_to(map_spacex)

# Mostrar el mapa
map_spacex
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ab8a6eb2e9411f6eb665e9ae420fd72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ab8a6eb2e9411f6eb665e9ae420fd72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ab8a6eb2e9411f6eb665e9ae420fd72 = L.map(
#                 &quot;map_9ab8a6eb2e9411f6eb665e9ae420fd72&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b30c6025c095e57bc6308fe29e62a044 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9ab8a6eb2e9411f6eb665e9ae420fd72);
#
#
#             var marker_27384a21d0e73850d8b6119c6304f181 = L.marker(
#                 [28.5618571, -80.577366],
#                 {}
#             ).addTo(map_9ab8a6eb2e9411f6eb665e9ae420fd72);
#
#
#             var icon_a2bd65c4b101de54aa87a16b6edbda60 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;rocket&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_27384a21d0e73850d8b6119c6304f181.setIcon(icon_a2bd65c4b101de54aa87a16b6edbda60);
#
#
#         var popup_2976d011a4a7c838d1aa11c6d41f9322 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3bc7a05fe17f07a878118d287b55ad5 = $(`&lt;div id=&quot;html_e3bc7a05fe17f07a878118d287b55ad5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC 40&lt;/div&gt;`)[0];
#                 popup_2976d011a4a7c838d1aa11c6d41f9322.setContent(html_e3bc7a05fe17f07a878118d287b55ad5);
#
#
#
#         marker_27384a21d0e73850d8b6119c6304f181.bindPopup(popup_2976d011a4a7c838d1aa11c6d41f9322)
#         ;
#
#
#
#
#             var marker_a7258190b7dab0e6041ecedea619c1fb = L.marker(
#                 [28.5618571, -80.577366],
#                 {}
#             ).addTo(map_9ab8a6eb2e9411f6eb665e9ae420fd72);
#
#
#             var icon_a4ea872f6518f7b25be80bfa5a689ab7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;rocket&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a7258190b7dab0e6041ecedea619c1fb.setIcon(icon_a4ea872f6518f7b25be80bfa5a689ab7);
#
#
#         var popup_98d400cd50dca371918083f20cbd2c3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b463caa7244c2ad1eb66c41a653563eb = $(`&lt;div id=&quot;html_b463caa7244c2ad1eb66c41a653563eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC 40&lt;/div&gt;`)[0];
#                 popup_98d400cd50dca371918083f20cbd2c3f.setContent(html_b463caa7244c2ad1eb66c41a653563eb);
#
#
#
#         marker_a7258190b7dab0e6041ecedea619c1fb.bindPopup(popup_98d400cd50dca371918083f20cbd2c3f)
#         ;
#
#
#
#
#             var marker_ec6d4e32f252ebf4b9cd37b7fa079bac = L.marker(
#                 [28.5618571, -80.577366],
#                 {}
#             ).addTo(map_9ab8a6eb2e9411f6eb665e9ae420fd72);
#
#
#             var icon_94d382a45edbb8e71a8d292e962bed92 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;rocket&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ec6d4e32f252ebf4b9cd37b7fa079bac.setIcon(icon_94d382a45edbb8e71a8d292e962bed92);
#
#
#         var popup_adbb14fe7da1192214fb9c21a8730f55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e8784ee1f71eb0ac7236ac607767137 = $(`&lt;div id=&quot;html_7e8784ee1f71eb0ac7236ac607767137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC 40&lt;/div&gt;`)[0];
#                 popup_adbb14fe7da1192214fb9c21a8730f55.setContent(html_7e8784ee1f71eb0ac7236ac607767137);
#
#
#
#         marker_ec6d4e32f252ebf4b9cd37b7fa079bac.bindPopup(popup_adbb14fe7da1192214fb9c21a8730f55)
#         ;
#
#
#
#
#             var marker_b9080823d2825ad9fd0f9e7b050bf37e = L.marker(
#                 [34.632093, -120.610829],
#                 {}
#             ).addTo(map_9ab8a6eb2e9411f6eb665e9ae420fd72);
#
#
#             var icon_c900b722d17e07d119ea171abe3bcc8c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;rocket&quot;, &quot

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv"
df_s = pd.read_csv(url)
df_s.head()
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %% [markdown]
# Now, we can take a look at what are the coordinates for each site.

# %%
df_s = df_s[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = df_s.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610746

# %% [markdown]
# We first need to create a folium Map object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use folium.Circle to add a highlighted circle are with a test label on a specific coordinate. For example,

# %%
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))

# Create a blue  circle at NASA Johnson Space Center's coordinate with a icon showin its name
marker = folium.map.Marker(
    nasa_coordinate,
   # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11e662bd2a5de9aab1acdb7659b1c62d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11e662bd2a5de9aab1acdb7659b1c62d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11e662bd2a5de9aab1acdb7659b1c62d = L.map(
#                 &quot;map_11e662bd2a5de9aab1acdb7659b1c62d&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db43396df5f274d2f8de0e66e9f49307 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_11e662bd2a5de9aab1acdb7659b1c62d);
#
#
#             var circle_4bb4025c815d75a0fc79092ce1ccd325 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_11e662bd2a5de9aab1acdb7659b1c62d);
#
#
#         var popup_7d6b7b6f5128a14ebe2cefe00caff6fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd2d34625e0839a64fb46eb8dd18e5fc = $(`&lt;div id=&quot;html_dd2d34625e0839a64fb46eb8dd18e5fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_7d6b7b6f5128a14ebe2cefe00caff6fd.setContent(html_dd2d34625e0839a64fb46eb8dd18e5fc);
#
#
#
#         circle_4bb4025c815d75a0fc79092ce1ccd325.bindPopup(popup_7d6b7b6f5128a14ebe2cefe00caff6fd)
#         ;
#
#
#
#
#             var marker_cb05fbc4d502ccd9dadf050704da521d = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_11e662bd2a5de9aab1acdb7659b1c62d);
#
#
#             var div_icon_88f938a2ab0cf099b70471f980c25e77 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_cb05fbc4d502ccd9dadf050704da521d.setIcon(div_icon_88f938a2ab0cf099b70471f980c25e77);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# An example of folium.Circle

# %%
folium.Circle(nasa_coordinate, radius=1000, color='#000000',
             fill=True).add_child(folium.Popup(...))

# %%
folium.map.Marker(nasa_coordinate, icon=DivIcon(icon_size=(20,20),
                                               icon_anchor=(0,0),
                                               html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate.

# %% [markdown]
# ## TASK 2
# Mark the success/failed launched for each site on the map

# %%
site_map = folium.Map(location=[0, 0], zoom_start=2)  # Puedes ajustar la ubicación y el nivel de zoom según tus necesidades

# %%
for index, launch in df_s.iterrows():
    # Obtener la información del lanzamiento
    launch_result = launch['Launch Site']
    launch_location = [launch['Lat'], launch['Long']]
    launch_name = launch['Launch Site']
    
    # Definir el color del marcador según el resultado del lanzamiento
    marker_color = 'green' if launch_result else 'red'
    
    # Agregar marcador al mapa
    folium.Marker(location=launch_location, popup=f"{launch_name} - {'Success' if launch_result else 'Failed'}",
                  icon=folium.Icon(color=marker_color)).add_to(map_object)

site_map.save('spacex_launch_map.html')  # Guardar como archivo HTML
# O mostrar directamente en el script
map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cc5215cda8e23ce6195547d027ab90b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cc5215cda8e23ce6195547d027ab90b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cc5215cda8e23ce6195547d027ab90b = L.map(
#                 &quot;map_0cc5215cda8e23ce6195547d027ab90b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e91ea1d38b8a3745f159405b03b158e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0cc5215cda8e23ce6195547d027ab90b);
#
#
#             var marker_2fe35b902fb0db8b0c8c116e7a97a261 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_0cc5215cda8e23ce6195547d027ab90b);
#
#
#             var icon_ddeb4e17b8abbee0fb419b06156bcd55 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2fe35b902fb0db8b0c8c116e7a97a261.setIcon(icon_ddeb4e17b8abbee0fb419b06156bcd55);
#
#
#         var popup_92a0623dbdd87a3c3e7988aa1bba5245 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2aa49e10ce47bcc3a879d726487be92a = $(`&lt;div id=&quot;html_2aa49e10ce47bcc3a879d726487be92a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Success&lt;/div&gt;`)[0];
#                 popup_92a0623dbdd87a3c3e7988aa1bba5245.setContent(html_2aa49e10ce47bcc3a879d726487be92a);
#
#
#
#         marker_2fe35b902fb0db8b0c8c116e7a97a261.bindPopup(popup_92a0623dbdd87a3c3e7988aa1bba5245)
#         ;
#
#
#
#
#             var marker_7fc35f2686fde35d1afb9c17c8f04d33 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_0cc5215cda8e23ce6195547d027ab90b);
#
#
#             var icon_7c575f01b4235a02ee6f94a5ef29cc08 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7fc35f2686fde35d1afb9c17c8f04d33.setIcon(icon_7c575f01b4235a02ee6f94a5ef29cc08);
#
#
#         var popup_4884e2715d58a1205d2a12f88e33defa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_999db58f1e8f774df847959adae65095 = $(`&lt;div id=&quot;html_999db58f1e8f774df847959adae65095&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Success&lt;/div&gt;`)[0];
#                 popup_4884e2715d58a1205d2a12f88e33defa.setContent(html_999db58f1e8f774df847959adae65095);
#
#
#
#         marker_7fc35f2686fde35d1afb9c17c8f04d33.bindPopup(popup_4884e2715d58a1205d2a12f88e33defa)
#         ;
#
#
#
#
#             var marker_5727a43f22161987c046b0f2951e0ef3 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_0cc5215cda8e23ce6195547d027ab90b);
#
#
#             var icon_50eaebae8017ffa690f89216ed1a375d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5727a43f22161987c046b0f2951e0ef3.setIcon(icon_50eaebae8017ffa690f89216ed1a375d);
#
#
#         var popup_1470fd42b8d8452b92065af406688376 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a1e77111038ba73fa7bfbdf90fdb223 = $(`&lt;div id=&quot;html_6a1e77111038ba73fa7bfbdf90fdb223&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Success&lt;/div&gt;`)[0];
#                 popup_1470fd42b8d8452b92065af406688376.setContent(html_6a1e77111038ba73fa7bfbdf90fdb223);
#
#
#
#         marker_5727a43f22161987c046b0f2951e0ef3.bindPopup(popup_1470fd42b8d8452b92065af406688376)
#         ;
#
#
#
#
#             var marker_c56769e6c836f5a45b98198afad05d5c = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_0cc5215cda8e23ce6195547d027ab90b);
#
#
#             var icon_9ba78bfaaf724bd594396a1e3eda77b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0

# %%
df_s.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %%
# Let's first create a marker cluster object
marker_cluster = MarkerCluster()

# %% [markdown]
# #### Create a new column in launch_sites dataframe called marker_color to store the marker ccolors based on the class value

# %%
import pandas as pd

# Supongamos que ya tienes tu DataFrame llamado launch_sites
# Aquí hay un ejemplo de cómo podrías tenerlo:

# launch_sites = pd.DataFrame({
#     'Site': ['Site1', 'Site2', 'Site3'],
#     'Class': ['A', 'B', 'C'],
#     'Latitude': [28.562302, 34.632834, 40.712776],
#     'Longitude': [-80.577356, -120.573332, -74.005974]
# })

# Asigna colores a las clases
class_colors = {'A': 'red', 'B': 'blue', 'C': 'green'}  # Puedes cambiar los colores según tus preferencias

# Crea la nueva columna 'marker_color' basada en la columna 'Class'
df_s['marker_color'] = df_s['class'].map(class_colors)

# Muestra el DataFrame actualizado
print(df_s)
# Out:
#      Launch Site        Lat        Long  class marker_color
# 0    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 1    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 2    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 3    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 4    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 5    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 6    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 7    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 8    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 9    CCAFS LC-40  28.562302  -80.577356      0          NaN
# 10   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 11   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 12   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 13   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 14   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 15   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 16   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 17   CCAFS LC-40  28.562302  -80.577356      1          NaN
# 18   CCAFS LC-40  28.562302  -80.577356      1          NaN
# 19   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 20   CCAFS LC-40  28.562302  -80.577356      1          NaN
# 21   CCAFS LC-40  28.562302  -80.577356      1          NaN
# 22   CCAFS LC-40  28.562302  -80.577356      1          NaN
# 23   CCAFS LC-40  28.562302  -80.577356      0          NaN
# 24   CCAFS LC-40  28.562302  -80.577356      1          NaN
# 25   CCAFS LC-40  28.562302  -80.577356      1          NaN
# 26   VAFB SLC-4E  34.632834 -120.610746      0          NaN
# 27   VAFB SLC-4E  34.632834 -120.610746      0          NaN
# 28   VAFB SLC-4E  34.632834 -120.610746      1          NaN
# 29   VAFB SLC-4E  34.632834 -120.610746      1          NaN
# 30   VAFB SLC-4E  34.632834 -120.610746      1          NaN
# 31   VAFB SLC-4E  34.632834 -120.610746      1          NaN
# 32   VAFB SLC-4E  34.632834 -120.610746      0          NaN
# 33   VAFB SLC-4E  34.632834 -120.610746      0          NaN
# 34   VAFB SLC-4E  34.632834 -120.610746      0          NaN
# 35   VAFB SLC-4E  34.632834 -120.610746      0          NaN
# 36    KSC LC-39A  28.573255  -80.646895      1          NaN
# 37    KSC LC-39A  28.573255  -80.646895      0          NaN
# 38    KSC LC-39A  28.573255  -80.646895      1          NaN
# 39    KSC LC-39A  28.573255  -80.646895      1          NaN
# 40    KSC LC-39A  28.573255  -80.646895      0          NaN
# 41    KSC LC-39A  28.573255  -80.646895      1          NaN
# 42    KSC LC-39A  28.573255  -80.646895      1          NaN
# 43    KSC LC-39A  28.573255  -80.646895      0          NaN
# 44    KSC LC-39A  28.573255  -80.646895      1          NaN
# 45    KSC LC-39A  28.573255  -80.646895      1          NaN
# 46    KSC LC-39A  28.573255  -80.646895      1          NaN
# 47    KSC LC-39A  28.573255  -80.646895      1          NaN
# 48    KSC LC-39A  28.573255  -80.646895      1          NaN
# 49  CCAFS SLC-40  28.563197  -80.576820      1          NaN
# 50  CCAFS SLC-40  28.563197  -80.576820      1          NaN
# 51  CCAFS SLC-40  28.563197  -80.576820      0          NaN
# 52  CCAFS SLC-40  28.563197  -80.576820      0          NaN
# 53  CCAFS SLC-40  28.563197  -80.576820      0          NaN
# 54  CCAFS SLC-40  28.563197  -80.576820      1          NaN
# 55  CCAFS SLC-40  28.563197  -80.576820      0          NaN

# %% [markdown]
# TODO: For each launch result in spacex_df data frame, add a folium.marker to marker_cluster

# %%
import folium
from folium.plugins import MarkerCluster

# Crear un objeto de mapa
site_map = folium.Map(location=[0, 0], zoom_start=2)

# Crear un clúster de marcadores
marker_cluster = MarkerCluster()
site_map.add_child(marker_cluster)

# Iterar sobre cada fila en el DataFrame
for index, row in df_s.iterrows():
    # Crear un objeto Marker con sus coordenadas y personalizar su ícono
    icon = folium.Icon(color='white', icon_color=row['marker_color'])
    marker = folium.Marker(location=[row['Lat'], row['Long']], icon=icon)
    
    # Añadir el marcador al clúster
    marker_cluster.add_child(marker)

# Mostrar el mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_417816037b2f9194513060dd525ca711 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_417816037b2f9194513060dd525ca711&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_417816037b2f9194513060dd525ca711 = L.map(
#                 &quot;map_417816037b2f9194513060dd525ca711&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f29c5d0ab9631154c3da5d73467ef64 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_417816037b2f9194513060dd525ca711);
#
#
#             var marker_cluster_bf9707a11b109beebd7571d5998202d5 = L.markerClusterGroup(
#                 {}
#             );
#             map_417816037b2f9194513060dd525ca711.addLayer(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var marker_7a502029adccd3366e09111b9fe1bd57 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_9fab10fd611f4d20f1db6824513ce62a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7a502029adccd3366e09111b9fe1bd57.setIcon(icon_9fab10fd611f4d20f1db6824513ce62a);
#
#
#             var marker_ad96f2c4b5421c2c0191414fbb3e5da7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_c09996dbbfec6eaeb964536eff4447d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ad96f2c4b5421c2c0191414fbb3e5da7.setIcon(icon_c09996dbbfec6eaeb964536eff4447d6);
#
#
#             var marker_514a246be3b940375c6ee1ebdef71edf = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_e997a0bb84b980ee5604e492a8be6ab5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_514a246be3b940375c6ee1ebdef71edf.setIcon(icon_e997a0bb84b980ee5604e492a8be6ab5);
#
#
#             var marker_97decced7555a0b9ae396241ae75231a = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_e08c5ac2f6eccb0cce90ad063b7e6f80 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97decced7555a0b9ae396241ae75231a.setIcon(icon_e08c5ac2f6eccb0cce90ad063b7e6f80);
#
#
#             var marker_c99dd8e8cb5223820e76b98bfb083c7f = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_5a9acc82df7a066c7545a731e74efc5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c99dd8e8cb5223820e76b98bfb083c7f.setIcon(icon_5a9acc82df7a066c7545a731e74efc5c);
#
#
#             var marker_d22145507f2a68aac5f5d6238007215e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf

# %% [markdown]
# #### Task 3 Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.
#
# Let's first add a MousePosition on the map to get coordinate for a mouse over a point on the map. As much, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_417816037b2f9194513060dd525ca711 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_417816037b2f9194513060dd525ca711&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_417816037b2f9194513060dd525ca711 = L.map(
#                 &quot;map_417816037b2f9194513060dd525ca711&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f29c5d0ab9631154c3da5d73467ef64 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_417816037b2f9194513060dd525ca711);
#
#
#             var marker_cluster_bf9707a11b109beebd7571d5998202d5 = L.markerClusterGroup(
#                 {}
#             );
#             map_417816037b2f9194513060dd525ca711.addLayer(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var marker_7a502029adccd3366e09111b9fe1bd57 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_9fab10fd611f4d20f1db6824513ce62a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7a502029adccd3366e09111b9fe1bd57.setIcon(icon_9fab10fd611f4d20f1db6824513ce62a);
#
#
#             var marker_ad96f2c4b5421c2c0191414fbb3e5da7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_c09996dbbfec6eaeb964536eff4447d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ad96f2c4b5421c2c0191414fbb3e5da7.setIcon(icon_c09996dbbfec6eaeb964536eff4447d6);
#
#
#             var marker_514a246be3b940375c6ee1ebdef71edf = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_e997a0bb84b980ee5604e492a8be6ab5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_514a246be3b940375c6ee1ebdef71edf.setIcon(icon_e997a0bb84b980ee5604e492a8be6ab5);
#
#
#             var marker_97decced7555a0b9ae396241ae75231a = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_e08c5ac2f6eccb0cce90ad063b7e6f80 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97decced7555a0b9ae396241ae75231a.setIcon(icon_e08c5ac2f6eccb0cce90ad063b7e6f80);
#
#
#             var marker_c99dd8e8cb5223820e76b98bfb083c7f = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_bf9707a11b109beebd7571d5998202d5);
#
#
#             var icon_5a9acc82df7a066c7545a731e74efc5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: NaN, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# TODO: Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch

# %%
# Definir las coordenadas de las líneas de costa
coastline1_Lat = 29.12345
coastline1_Long = -81.23456
coastline2_lat = 30.56789
coastline2_lon = -79.87654

# Lista de coordenadas de las líneas de costa
coastlines = [(coastline1_Lat, coastline1_Long), (coastline2_lat, coastline2_lon)]

# Resto del código...

# %%
from math import radians, sin, cos, sqrt, atan2

def calculate_distance(lat1, lon1, lat2, lon2):
    # Radio de la Tierra en kilómetros
    R = 6371.0

    # Convertir las coordenadas de grados a radianes
    lat1_rad = radians(lat1)
    lon1_rad = radians(lon1)
    lat2_rad = radians(lat2)
    lon2_rad = radians(lon2)

    # Diferencia de coordenadas
    dlon = lon2_rad - lon1_rad
    dlat = lat2_rad - lat1_rad

    # Fórmula de Haversine para calcular la distancia
    a = sin(dlat / 2)**2 + cos(lat1_rad) * cos(lat2_rad) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    # Distancia en kilómetros
    distance = R * c

    return distance

def find_closest_coastline(launch_site_lat, launch_site_lon, coastlines):
    closest_coastline = None
    min_distance = float('inf')

    for coastline in coastlines:
        coastline_lat, coastline_lon = coastline
        distance = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

        if distance < min_distance:
            min_distance = distance
            closest_coastline = coastline

    return closest_coastline

# Ejemplo de uso
launch_site_lat = 28.56367
launch_site_lon = -80.57163
coastlines = [(coastline1_Lat, coastline1_Long), (coastline2_lat, coastlines)]

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e1/58/9289c6a03116025cdb61461d99b2493daa4967a80b13755463d71a0affeb/geopy-2.4.0-py3-none-any.whl.metadata
#   Downloading geopy-2.4.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 129.2 kB/s eta 0:00:00:--:--
# Downloading geopy-2.4.0-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 117.6 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.0

# %%
# Ejemplo de coordenadas (reemplázalas con tus propias coordenadas)
your_launch_site_latitude = 40.7128
your_launch_site_longitude = -74.0060
closest_coastline_latitude = 41.8781
closest_coastline_longitude = -87.6298

# %%
import folium
from folium.features import DivIcon
from geopy.distance import geodesic

# Función para calcular la distancia entre dos puntos geográficos
def calculate_distance(point1, point2):
    return geodesic(point1, point2).kilometers

# Coordenadas del lanzamiento y el punto más cercano de la costa
launch_site_coordinates = (your_launch_site_latitude, your_launch_site_longitude)
closest_coastline_coordinates = (closest_coastline_latitude, closest_coastline_longitude)

# Calcular la distancia entre el sitio de lanzamiento y el punto más cercano de la costa
distance = calculate_distance(launch_site_coordinates, closest_coastline_coordinates)
# Crear un mapa centrado en el sitio de lanzamiento
map_center = launch_site_coordinates
my_map = folium.Map(location=map_center, zoom_start=10)

# Añadir un marcador en el punto más cercano de la costa
distance_marker = folium.Marker(
    location=closest_coastline_coordinates,
    icon=DivIcon(
        icon_size=(20, 20),
        icon_anchor=(0, 0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance),
    )
)

# Añadir el marcador al mapa
distance_marker.add_to(my_map)

# Mostrar el mapa
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9698c453f41c3d16d6692e27dbcd1863 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9698c453f41c3d16d6692e27dbcd1863&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9698c453f41c3d16d6692e27dbcd1863 = L.map(
#                 &quot;map_9698c453f41c3d16d6692e27dbcd1863&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5f62fdac375c027b7636ac2fc4045cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9698c453f41c3d16d6692e27dbcd1863);
#
#
#             var marker_ac188324b656eb2b5d20f235dc02757a = L.marker(
#                 [41.8781, -87.6298],
#                 {}
#             ).addTo(map_9698c453f41c3d16d6692e27dbcd1863);
#
#
#             var div_icon_4173d7ea2032e8aad71b2eaaf135cee0 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003e   1147.19 KM\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_ac188324b656eb2b5d20f235dc02757a.setIcon(div_icon_4173d7ea2032e8aad71b2eaaf135cee0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# TODO: Draw a PolyLine between a launch site to the selected coastline point

# %%
# Ejemplo de coordenadas para la línea (reemplázalas con tus propias coordenadas)
coastline_coordinates = [(lat1, lon1), (lat2, lon2), (lat3, lon3), ...]  # Agrega todas las coordenadas de la costa
launch_site_coordinates = (your_launch_site_latitude, your_launch_site_longitude)

# Crear un objeto `folium.PolyLine` utilizando las coordenadas de la costa y del sitio de lanzamiento
lines = folium.PolyLine(locations=[coastline_coordinates, launch_site_coordinates], weight=1)

# Añadir la línea al mapa
site_map.add_child(lines)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 2
#       1 # Ejemplo de coordenadas para la línea (reemplázalas con tus propias coordenadas)
# ----> 2 coastline_coordinates = [(lat1, lon1), (lat2, lon2), (lat3, lon3), ...]  # Agrega todas las coordenadas de la costa
#       3 launch_site_coordinates = (your_launch_site_latitude, your_launch_site_longitude)
#       5 # Crear un objeto `folium.PolyLine` utilizando las coordenadas de la costa y del sitio de lanzamiento
#
# NameError: name 'lat1' is not defined

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 2
#       1 # Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
# ----> 2 lines=folium.PolyLine(locations=coordinates, weight=1)
#       3 site_map.add_child(lines)
#
# NameError: name 'coordinates' is not defined

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

# %%
import folium
from folium import plugins
from geopy.distance import geodesic

# Coordenadas del sitio de lanzamiento de SpaceX (por ejemplo, el Kennedy Space Center en Florida)
launch_site_coords = (28.3922, -80.6077)

# Crear un mapa centrado en el sitio de lanzamiento
map_spacex = folium.Map(location=launch_site_coords, zoom_start=10)

# Coordenadas de las ciudades, ferrocarriles, carreteras, etc. (ejemplo)
city_coords = [(28.6139, -77.2090), (34.0522, -118.2437)]  # Agrega más según tu dataset

# Calcular la distancia a la ciudad más cercana
closest_city = min(city_coords, key=lambda x: geodesic(launch_site_coords, x).km)
distance_to_closest_city = f"{geodesic(launch_site_coords, closest_city).km:.2f} km"

# Agregar marcador para el sitio de lanzamiento
folium.Marker(
    location=launch_site_coords,
    popup=f"Distancia a la ciudad más cercana: {distance_to_closest_city}",
    icon=folium.Icon(color="red")
).add_to(map_spacex)

# Agregar marcadores para las ciudades
for city_coord in city_coords:
    folium.Marker(
        location=city_coord,
        icon=folium.Icon(color="blue")
    ).add_to(map_spacex)

# Dibujar línea entre el marcador y el sitio de lanzamiento
folium.PolyLine([launch_site_coords, closest_city], color="green").add_to(map_spacex)

# Guardar el mapa en un archivo HTML
map_spacex.save("spacex_map.html")
